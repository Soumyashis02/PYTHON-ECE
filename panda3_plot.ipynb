# %%
import pandas as pd
import matplotlib.pyplot as plt
class CreateDataFrame:
    def main():
        SampleData={
            "Name": ["Tests1","Tests2","Tests3","Tests4","Tests5","Tests6"],
            "Age" : [25,52,65,94,35,64],
            "Id"  : [3301,2022,4512,2879,2645,7594],
        }
        df=pd.DataFrame(SampleData)
        print(df)
        df.to_csv('File123.csv',index="False",header="False")
        df.plot(marker="*")
        plt.show()
CreateDataFrame.main()
# Out:
#      Name  Age    Id
# 0  Tests1   25  3301
# 1  Tests2   52  2022
# 2  Tests3   65  4512
# 3  Tests4   94  2879
# 4  Tests5   35  2645
# 5  Tests6   64  7594
